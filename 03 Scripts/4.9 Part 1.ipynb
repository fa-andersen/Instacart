# %% [markdown]
# # 4.9 Part 1: Instacart
#
#
# ### This script contains the following points:
# #### 01. Import libraries and data
# #### 02. Descriptive Analysis
# #### 03. Wrangle Data
# #### 04. Data Quality & Consistency Checks
# #### 05. Combine Data
# #### 06. Export data

# %% [markdown]
# # 01 Import libraries and Data

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Create data path
path = r'C:\Users\fa_an\OneDrive\CareerFoundry\Tasks\Data Analytics Immersion\Tasks 4.1-4.10\02_2024 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\fa_an\\OneDrive\\CareerFoundry\\Tasks\\Data Analytics Immersion\\Tasks 4.1-4.10\\02_2024 Instacart Basket Analysis'

# %%
#Import customers.csv df
df_customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %% [markdown]
# # 02 Descriptive Analysis

# %%
df_customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customers.info
# Out:
# <bound method DataFrame.info of         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285
# 2                  2    married   99568
# 3                  0     single   42049
# 4                  1    married   40374
# ...              ...        ...     ...
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095
#
# [206209 rows x 10 columns]>

# %%
df_customers.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
df_customers.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# # 03 Wrangle Data

# %%
#create vars_list to not import First Name, Surnam
vars_list = ['user_id', 'Gender', 'STATE', 'Age', 'date_joined', 'n_dependants', 'fam_status', 'income']

# %%
#re-import customers.csv using vars_list
df_customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), usecols = vars_list)

# %%
df_customers.head()
# Out:
#    user_id  Gender       STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female    Missouri   48    1/1/2017             3    married
# 1    33890  Female  New Mexico   36    1/1/2017             0     single
# 2    65803    Male       Idaho   35    1/1/2017             2    married
# 3   125935  Female        Iowa   40    1/1/2017             0     single
# 4   130797  Female    Maryland   26    1/1/2017             1    married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %%
#update column names
df_customers.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
df_customers.rename(columns = {'n_dependants' : 'total_dependants'}, inplace = True)

# %%
df_customers.rename(columns = {'fam_status' : 'family_status'}, inplace = True)

# %%
df_customers.head()
# Out:
#    user_id  Gender       State  Age date_joined  total_dependants  \
# 0    26711  Female    Missouri   48    1/1/2017                 3
# 1    33890  Female  New Mexico   36    1/1/2017                 0
# 2    65803    Male       Idaho   35    1/1/2017                 2
# 3   125935  Female        Iowa   40    1/1/2017                 0
# 4   130797  Female    Maryland   26    1/1/2017                 1
#
#   family_status  income
# 0       married  165665
# 1        single   59285
# 2       married   99568
# 3        single   42049
# 4       married   40374

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           206209 non-null  int64
#  1   Gender            206209 non-null  object
#  2   State             206209 non-null  object
#  3   Age               206209 non-null  int64
#  4   date_joined       206209 non-null  object
#  5   total_dependants  206209 non-null  int64
#  6   family_status     206209 non-null  object
#  7   income            206209 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 12.6+ MB

# %% [markdown]
# # 04 Data Quality & Consistency Checks

# %%
#find missing values & frequency of variables
df_customers.isnull().sum()
# Out:
# user_id             0
# Gender              0
# State               0
# Age                 0
# date_joined         0
# total_dependants    0
# family_status       0
# income              0
# dtype: int64

# %%
df_customers['Gender'].value_counts(dropna=False)
# Out:
# Gender
# Male      104067
# Female    102142
# Name: count, dtype: int64

# %%
df_customers['State'].value_counts(dropna=False)
# Out:
# State
# Florida                 4044
# Colorado                4044
# Illinois                4044
# Alabama                 4044
# District of Columbia    4044
# Hawaii                  4044
# Arizona                 4044
# Connecticut             4044
# California              4044
# Indiana                 4044
# Arkansas                4044
# Alaska                  4044
# Delaware                4044
# Iowa                    4044
# Idaho                   4044
# Georgia                 4044
# Wyoming                 4043
# Mississippi             4043
# Oklahoma                4043
# Utah                    4043
# New Hampshire           4043
# Kentucky                4043
# Maryland                4043
# Rhode Island            4043
# Massachusetts           4043
# Michigan                4043
# New Jersey              4043
# Kansas                  4043
# South Dakota            4043
# Minnesota               4043
# Tennessee               4043
# New York                4043
# Washington              4043
# Louisiana               4043
# Montana                 4043
# North Dakota            4043
# Wisconsin               4043
# Nebraska                4043
# Vermont                 4043
# Nevada                  4043
# Maine                   4043
# North Carolina          4043
# West Virginia           4043
# Virginia                4043
# Oregon                  4043
# New Mexico              4043
# Texas                   4043
# Pennsylvania            4043
# Ohio                    4043
# South Carolina          4043
# Missouri                4043
# Name: count, dtype: int64

# %%
df_customers['Age'].value_counts(dropna=False)
# Out:
# Age
# 19    3329
# 55    3317
# 51    3317
# 56    3306
# 32    3305
#       ...
# 65    3145
# 25    3127
# 66    3114
# 50    3102
# 36    3101
# Name: count, Length: 64, dtype: int64

# %%
df_customers['date_joined'].value_counts(dropna = False)
# Out:
# date_joined
# 9/17/2018     213
# 2/10/2018     212
# 4/1/2019      211
# 9/21/2019     211
# 12/19/2017    210
#              ...
# 9/1/2018      141
# 1/22/2018     140
# 11/24/2017    139
# 7/18/2019     138
# 8/6/2018      128
# Name: count, Length: 1187, dtype: int64

# %%
df_customers['total_dependants'].value_counts(dropna = False)
# Out:
# total_dependants
# 0    51602
# 3    51594
# 1    51531
# 2    51482
# Name: count, dtype: int64

# %%
df_customers['family_status'].value_counts(dropna = False)
# Out:
# family_status
# married                             144906
# single                               33962
# divorced/widowed                     17640
# living with parents and siblings      9701
# Name: count, dtype: int64

# %%
df_customers['income'].value_counts(dropna = False)
# Out:
# income
# 57192     10
# 95891     10
# 95710     10
# 97532      9
# 98675      9
#           ..
# 73141      1
# 71524      1
# 74408      1
# 44780      1
# 148828     1
# Name: count, Length: 108012, dtype: int64

# %%
df_customers.describe()
# Out:
#              user_id            Age  total_dependants         income
# count  206209.000000  206209.000000     206209.000000  206209.000000
# mean   103105.000000      49.501646          1.499823   94632.852548
# std     59527.555167      18.480962          1.118433   42473.786988
# min         1.000000      18.000000          0.000000   25903.000000
# 25%     51553.000000      33.000000          0.000000   59874.000000
# 50%    103105.000000      49.000000          1.000000   93547.000000
# 75%    154657.000000      66.000000          3.000000  124244.000000
# max    206209.000000      81.000000          3.000000  593901.000000

# %%
#change dtype of date_joined from int64 to datetime
df_customers['date_joined'] = pd.to_datetime(df_customers['date_joined'])

# %%
df_customers['date_joined'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#change date_joined date/time format to be MDY
df_customers['date_joined'] = df_customers['date_joined'].dt.strftime('%m-%d-%Y')

# %%
df_customers.head()
# Out:
#    user_id  Gender       State  Age date_joined  total_dependants  \
# 0    26711  Female    Missouri   48  01-01-2017                 3
# 1    33890  Female  New Mexico   36  01-01-2017                 0
# 2    65803    Male       Idaho   35  01-01-2017                 2
# 3   125935  Female        Iowa   40  01-01-2017                 0
# 4   130797  Female    Maryland   26  01-01-2017                 1
#
#   family_status  income
# 0       married  165665
# 1        single   59285
# 2       married   99568
# 3        single   42049
# 4       married   40374

# %%
#finding mixed-type data
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].map(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)
else:
    print('All is ok')
# Out:
# All is ok

# %%
#finding duplicates
df_dups = df_customers[df_customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, Gender, State, Age, date_joined, total_dependants, family_status, income]
# Index: []

# %%
#no dupes found!

# %%
df_customers.shape
# Out:
# (206209, 8)

# %% [markdown]
# # 05 Combine Data

# %%
#Combine your customer data with the rest of your prepared Instacart data.
#(Hint: Make sure the key columns are the same data type!)

# %%
#import ords_prods_grouped.pkl
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_grouped.pkl'))

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order first_or_repeat_order  \
# 0                  8                     NaN           First Order
# 1                  7                    15.0          Repeat Order
# 2                 12                    21.0          Repeat Order
# 3                  7                    29.0          Repeat Order
# 4                 15                    28.0          Repeat Order
#
#    product_id  add_to_cart_order  ...        price_label     busiest_day  \
# 0         196                  1  ...  Mid-range product  Regularly busy
# 1         196                  1  ...  Mid-range product  Regularly busy
# 2         196                  1  ...  Mid-range product  Regularly busy
# 3         196                  1  ...  Mid-range product      Least busy
# 4         196                  1  ...  Mid-range product      Least busy
#
#      busiest_days  busiest_period_of_day  max_order  loyalty_flag  \
# 0  Regularly busy         Average Orders         10  New Customer
# 1    Slowest days         Average Orders         10  New Customer
# 2    Slowest days            Most Orders         10  New Customer
# 3    Slowest days         Average Orders         10  New Customer
# 4    Slowest days            Most Orders         10  New Customer
#
#   mean_product_price spending_flag median_days_between_orders  \
# 0           6.367797   Low Spender                       20.5
# 1           6.367797   Low Spender                       20.5
# 2           6.367797   Low Spender                       20.5
# 3           6.367797   Low Spender                       20.5
# 4           6.367797   Low Spender                       20.5
#
#     order_frequency_flag
# 0  Non-frequent customer
# 1  Non-frequent customer
# 2  Non-frequent customer
# 3  Non-frequent customer
# 4  Non-frequent customer
#
# [5 rows x 25 columns]

# %%
df_ords_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   order_id                    int64
#  1   user_id                     int64
#  2   eval_set                    object
#  3   order_number                int64
#  4   orders_day_of_week          int64
#  5   order_hour_of_day           int64
#  6   days_since_prior_order      float64
#  7   first_or_repeat_order       object
#  8   product_id                  int64
#  9   add_to_cart_order           int64
#  10  reordered                   int64
#  11  product_name                object
#  12  aisle_id                    int64
#  13  department_id               int64
#  14  prices                      float64
#  15  price_label                 object
#  16  busiest_day                 object
#  17  busiest_days                object
#  18  busiest_period_of_day       object
#  19  max_order                   int64
#  20  loyalty_flag                object
#  21  mean_product_price          float64
#  22  spending_flag               object
#  23  median_days_between_orders  float64
#  24  order_frequency_flag        object
# dtypes: float64(4), int64(11), object(10)
# memory usage: 6.0+ GB

# %%
#merge df_ords_prods and df_customers
df_merged = df_ords_prods.merge(df_customers, on = 'user_id', indicator = True)

# %%
df_merged.isnull().sum()

# %%
df_merged.head(25)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2539329        1    prior             1                   2
# 11   2539329        1    prior             1                   2
# 12   2398795        1    prior             2                   3
# 13    473747        1    prior             3                   3
# 14   2254736        1    prior             4                   4
# 15    431534        1    prior             5                   4
# 16   3367565        1    prior             6                   2
# 17    550135        1    prior             7                   1
# 18   3108588        1    prior             8                   1
# 19   2295261        1    prior             9                   1
# 20   2550362        1    prior            10                   4
# 21   2539329        1    prior             1                   2
# 22   2398795        1    prior             2                   3
# 23   2539329        1    prior             1                   2
# 24   2254736        1    prior             4                   4
#
#     order_hour_of_day  days_since_prior_order first_or_repeat_order  \
# 0                   8                     NaN           First Order
# 1                   7                    15.0          Repeat Order
# 2                  12                    21.0          Repeat Order
# 3                   7                    29.0          Repeat Order
# 4                  15                    28.0          Repeat Order
# 5                   7                    19.0          Repeat Order
# 6                   9                    20.0          Repeat Order
# 7                  14                    14.0          Repeat Order
# 8                  16                     0.0          Repeat Order
# 9                   8                    30.0          Repeat Order
# 10                  8                     NaN           First Order
# 11                  8                     NaN           First Order
# 12                  7                    15.0          Repeat Order
# 13                 12                    21.0          Repeat Order
# 14                  7                    29.0          Repeat Order
# 15                 15                    28.0          Repeat Order
# 16                  7                    19.0          Repeat Order
# 17                  9                    20.0          Repeat Order
# 18                 14                    14.0          Repeat Order
# 19                 16                     0.0          Repeat Order
# 20                  8                    30.0          Repeat Order
# 21                  8                     NaN           First Order
# 22                  7                    15.0          Repeat Order
# 23                  8                     NaN           First Order
# 24                  7                    29.0          Repeat Order
#
#     product_id  add_to_cart_order  ...  median_days_between_orders  \
# 0          196                  1  ...                        20.5
# 1          196                  1  ...                        20.5
# 2          196                  1  ...                        20.5
# 3          196                  1  ...                        20.5
# 4          196                  1  ...                        20.5
# 5          196                  1  ...                        20.5
# 6          196                  1  ...                        20.5
# 7          196                  2  ...                        20.5
# 8          196                  4  ...                        20.5
# 9          196                  1  ...                        20.5
# 10       14084                  2  ...                        20.5
# 11       12427                  3  ...                        20.5
# 12       12427                  3  ...                        20.5
# 13       12427                  2  ...                        20.5
# 14       12427                  2  ...                        20.5
# 15       12427                  2  ...                        20.5
# 16       12427                  2  ...                        20.5
# 17       12427                  3  ...                        20.5
# 18       12427                  1  ...                        20.5
# 19       12427                  6  ...                        20.5
# 20       12427                  9  ...                        20.5
# 21       26088                  4  ...                        20.5
# 22       26088                  5  ...                        20.5
# 23       26405                  5  ...                        20.5
# 24       26405                  5  ...                        20.5
#
#      order_frequency_flag  Gender    State  Age date_joined total_dependants  \
# 0   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 1   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 2   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 3   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 4   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 5   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 6   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 7   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 8   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 9   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 10  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 11  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 12  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 13  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 14  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 15  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 16  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 17  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 18  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 19  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 20  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 21  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 22  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 23  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 24  Non-frequent customer  Female  Alabama   31  02-17-2019                3
#
#    family_status income  _merge
# 0        married  40423    both
# 1        married  40423    both
# 2        married  40423    both
# 3        married  40423    both
# 4        married  40423    both
# 5        married  40423    both
# 6        married  40423    both
# 7        married  40423    both
# 8        married  40423    both
# 9        married  40423    both
# 10       married  40423    both
# 11       married  40423    both
# 12       married  40423    both
# 13       married  40423    both
# 14       married  40423    both
# 15       married  40423    both
# 16       married  40423    both
# 17       married  40423    both
# 18       married  40423    both
# 19       married  40423    both
# 20       married  40423    both
# 21       married  40423    both
# 22       married  40423    both
# 23       married  40423    both
# 24       married  40423    both
#
# [25 rows x 33 columns]

# %%
df_merged[df_merged['user_id'] == 1]
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2539329        1    prior             1                   2
# 11   2539329        1    prior             1                   2
# 12   2398795        1    prior             2                   3
# 13    473747        1    prior             3                   3
# 14   2254736        1    prior             4                   4
# 15    431534        1    prior             5                   4
# 16   3367565        1    prior             6                   2
# 17    550135        1    prior             7                   1
# 18   3108588        1    prior             8                   1
# 19   2295261        1    prior             9                   1
# 20   2550362        1    prior            10                   4
# 21   2539329        1    prior             1                   2
# 22   2398795        1    prior             2                   3
# 23   2539329        1    prior             1                   2
# 24   2254736        1    prior             4                   4
# 25   2398795        1    prior             2                   3
# 26    473747        1    prior             3                   3
# 27   2254736        1    prior             4                   4
# 28    431534        1    prior             5                   4
# 29   3367565        1    prior             6                   2
# 30    550135        1    prior             7                   1
# 31   3108588        1    prior             8                   1
# 32   2295261        1    prior             9                   1
# 33   2550362        1    prior            10                   4
# 34   2398795        1    prior             2                   3
# 35    431534        1    prior             5                   4
# 36   2398795        1    prior             2                   3
# 37    550135        1    prior             7                   1
# 38   2550362        1    prior            10                   4
# 39    473747        1    prior             3                   3
# 40   2254736        1    prior             4                   4
# 41    431534        1    prior             5                   4
# 42   3367565        1    prior             6                   2
# 43    550135        1    prior             7                   1
# 44   3108588        1    prior             8                   1
# 45   2295261        1    prior             9                   1
# 46   2550362        1    prior            10                   4
# 47    473747        1    prior             3                   3
# 48    431534        1    prior             5                   4
# 49    431534        1    prior             5                   4
# 50    431534        1    prior             5                   4
# 51   3108588        1    prior             8                   1
# 52   2295261        1    prior             9                   1
# 53   2550362        1    prior            10                   4
# 54   3108588        1    prior             8                   1
# 55   2295261        1    prior             9                   1
# 56   2550362        1    prior            10                   4
# 57   2550362        1    prior            10                   4
# 58   2550362        1    prior            10                   4
#
#     order_hour_of_day  days_since_prior_order first_or_repeat_order  \
# 0                   8                     NaN           First Order
# 1                   7                    15.0          Repeat Order
# 2                  12                    21.0          Repeat Order
# 3                   7                    29.0          Repeat Order
# 4                  15                    28.0          Repeat Order
# 5                   7                    19.0          Repeat Order
# 6                   9                    20.0          Repeat Order
# 7                  14                    14.0          Repeat Order
# 8                  16                     0.0          Repeat Order
# 9                   8                    30.0          Repeat Order
# 10                  8                     NaN           First Order
# 11                  8                     NaN           First Order
# 12                  7                    15.0          Repeat Order
# 13                 12                    21.0          Repeat Order
# 14                  7                    29.0          Repeat Order
# 15                 15                    28.0          Repeat Order
# 16                  7                    19.0          Repeat Order
# 17                  9                    20.0          Repeat Order
# 18                 14                    14.0          Repeat Order
# 19                 16                     0.0          Repeat Order
# 20                  8                    30.0          Repeat Order
# 21                  8                     NaN           First Order
# 22                  7                    15.0          Repeat Order
# 23                  8                     NaN           First Order
# 24                  7                    29.0          Repeat Order
# 25                  7                    15.0          Repeat Order
# 26                 12                    21.0          Repeat Order
# 27                  7                    29.0          Repeat Order
# 28                 15                    28.0          Repeat Order
# 29                  7                    19.0          Repeat Order
# 30                  9                    20.0          Repeat Order
# 31                 14                    14.0          Repeat Order
# 32                 16                     0.0          Repeat Order
# 33                  8                    30.0          Repeat Order
# 34                  7                    15.0          Repeat Order
# 35                 15                    28.0          Repeat Order
# 36                  7                    15.0          Repeat Order
# 37                  9                    20.0          Repeat Order
# 38                  8                    30.0          Repeat Order
# 39                 12                    21.0          Repeat Order
# 40                  7                    29.0          Repeat Order
# 41                 15                    28.0          Repeat Order
# 42                  7                    19.0          Repeat Order
# 43                  9                    20.0          Repeat Order
# 44                 14                    14.0          Repeat Order
# 45                 16                     0.0          Repeat Order
# 46                  8                    30.0          Repeat Order
# 47                 12                    21.0          Repeat Order
# 48                 15                    28.0          Repeat Order
# 49                 15                    28.0          Repeat Order
# 50                 15                    28.0          Repeat Order
# 51                 14                    14.0          Repeat Order
# 52                 16                     0.0          Repeat Order
# 53                  8                    30.0          Repeat Order
# 54                 14                    14.0          Repeat Order
# 55                 16                     0.0          Repeat Order
# 56                  8                    30.0          Repeat Order
# 57                  8                    30.0          Repeat Order
# 58                  8                    30.0          Repeat Order
#
#     product_id  add_to_cart_order  ...  median_days_between_orders  \
# 0          196                  1  ...                        20.5
# 1          196                  1  ...                        20.5
# 2          196                  1  ...                        20.5
# 3          196                  1  ...                        20.5
# 4          196                  1  ...                        20.5
# 5          196                  1  ...                        20.5
# 6          196                  1  ...                        20.5
# 7          196                  2  ...                        20.5
# 8          196                  4  ...                        20.5
# 9          196                  1  ...                        20.5
# 10       14084                  2  ...                        20.5
# 11       12427                  3  ...                        20.5
# 12       12427                  3  ...                        20.5
# 13       12427                  2  ...                        20.5
# 14       12427                  2  ...                        20.5
# 15       12427                  2  ...                        20.5
# 16       12427                  2  ...                        20.5
# 17       12427                  3  ...                        20.5
# 18       12427                  1  ...                        20.5
# 19       12427                  6  ...                        20.5
# 20       12427                  9  ...                        20.5
# 21       26088                  4  ...                        20.5
# 22       26088                  5  ...                        20.5
# 23       26405                  5  ...                        20.5
# 24       26405                  5  ...                        20.5
# 25       10258                  2  ...                        20.5
# 26       10258                  3  ...                        20.5
# 27       10258                  3  ...                        20.5
# 28       10258                  3  ...                        20.5
# 29       10258                  3  ...                        20.5
# 30       10258                  2  ...                        20.5
# 31       10258                  3  ...                        20.5
# 32       10258                  5  ...                        20.5
# 33       10258                  6  ...                        20.5
# 34       13176                  4  ...                        20.5
# 35       13176                  8  ...                        20.5
# 36       13032                  6  ...                        20.5
# 37       13032                  5  ...                        20.5
# 38       13032                  8  ...                        20.5
# 39       25133                  4  ...                        20.5
# 40       25133                  4  ...                        20.5
# 41       25133                  4  ...                        20.5
# 42       25133                  4  ...                        20.5
# 43       25133                  4  ...                        20.5
# 44       25133                  4  ...                        20.5
# 45       25133                  3  ...                        20.5
# 46       25133                  5  ...                        20.5
# 47       30450                  5  ...                        20.5
# 48       10326                  5  ...                        20.5
# 49       17122                  6  ...                        20.5
# 50       41787                  7  ...                        20.5
# 51       46149                  5  ...                        20.5
# 52       46149                  2  ...                        20.5
# 53       46149                  2  ...                        20.5
# 54       49235                  6  ...                        20.5
# 55       49235                  1  ...                        20.5
# 56       39657                  3  ...                        20.5
# 57       38928                  4  ...                        20.5
# 58       35951                  7  ...                        20.5
#
#      order_frequency_flag  Gender    State  Age date_joined total_dependants  \
# 0   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 1   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 2   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 3   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 4   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 5   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 6   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 7   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 8   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 9   Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 10  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 11  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 12  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 13  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 14  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 15  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 16  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 17  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 18  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 19  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 20  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 21  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 22  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 23  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 24  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 25  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 26  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 27  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 28  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 29  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 30  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 31  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 32  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 33  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 34  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 35  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 36  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 37  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 38  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 39  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 40  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 41  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 42  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 43  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 44  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 45  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 46  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 47  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 48  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 49  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 50  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 51  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 52  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 53  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 54  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 55  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 56  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 57  Non-frequent customer  Female  Alabama   31  02-17-2019                3
# 58  Non-frequent customer  Female  Alabama   31  02-17-2019                3
#
#    family_status income  _merge
# 0        married  40423    both
# 1        married  40423    both
# 2        married  40423    both
# 3        married  40423    both
# 4        married  40423    both
# 5        married  40423    both
# 6        married  40423    both
# 7        married  40423    both
# 8        married  40423    both
# 9        married  40423    both
# 10       married  40423    both
# 11       married  40423    both
# 12       married  40423    both
# 13       married  40423    both
# 14       married  40423    both
# 15       married  40423    both
# 16       married  40423    both
# 17       married  40423    both
# 18       married  40423    both
# 19       married  40423    both
# 20       married  40423    both
# 21       married  40423    both
# 22       married  40423    both
# 23       married  40423    both
# 24       married  40423    both
# 25       married  40423    both
# 26       married  40423    both
# 27       married  40423    both
# 28       married  40423    both
# 29       married  40423    both
# 30       married  40423    both
# 31       married  40423    both
# 32       married  40423    both
# 33       married  40423    both
# 34       married  40423    both
# 35       married  40423    both
# 36       married  40423    both
# 37       married  40423    both
# 38       married  40423    both
# 39       married  40423    both
# 40       married  40423    both
# 41       married  40423    both
# 42       married  40423    both
# 43       married  40423    both
# 44       married  40423    both
# 45       married  40423    both
# 46       married  40423    both
# 47       married  40423    both
# 48       married  40423    both
# 49       married  40423    both
# 50       married  40423    both
# 51       married  40423    both
# 52       married  40423    both
# 53       married  40423    both
# 54       married  40423    both
# 55       married  40423    both
# 56       married  40423    both
# 57       married  40423    both
# 58       married  40423    both
#
# [59 rows x 33 columns]

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.shape
# Out:
# (32404859, 33)

# %% [markdown]
# # 06 Export

# %%
#Export the merged file in pickle format as “ords_prods_customers.pkl”.
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_customers.pkl'))
