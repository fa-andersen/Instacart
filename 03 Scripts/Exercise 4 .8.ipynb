# %% [markdown]
# ## 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ### This script contains the following points:
# #### 1. Import libraries and data
# #### 2. Grouping Data
# #### 3. Grouping Data w/ Pandas
# #### 4. Aggregating Data w/ agg ()
# #### 5. Aggregating Data w/ transform ()
# #### 6. Deriving Columns w/ loc()
# #### 7. Task

# %% [markdown]
# # 1. Import Libraries & Data

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create data path
path = r'C:\Users\fa_an\OneDrive\CareerFoundry\Tasks\Data Analytics Immersion\Tasks 4.1-4.10\02_2024 Instacart Basket Analysis'

# %%
#import data - ords_prods_merge.pkl as df_ords_prods_merge
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_derived.pkl'))

# %%
#Create a subset
df = ords_prods_merge[:1000000]

# %%
#check shape
df.shape
# Out:
# (1000000, 19)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order first_or_repeat_order  \
# 0                  8                     NaN           First Order
# 1                  7                    15.0          Repeat Order
# 2                 12                    21.0          Repeat Order
# 3                  7                    29.0          Repeat Order
# 4                 15                    28.0          Repeat Order
#
#    product_id  add_to_cart_order  reordered product_name  aisle_id  \
# 0         196                  1          0         Soda        77
# 1         196                  1          1         Soda        77
# 2         196                  1          1         Soda        77
# 3         196                  1          1         Soda        77
# 4         196                  1          1         Soda        77
#
#    department_id  prices        price_label     busiest_day    busiest_days  \
# 0              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 1              7     9.0  Mid-range product  Regularly busy    Slowest days
# 2              7     9.0  Mid-range product  Regularly busy    Slowest days
# 3              7     9.0  Mid-range product      Least busy    Slowest days
# 4              7     9.0  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day
# 0        Average Orders
# 1        Average Orders
# 2           Most Orders
# 3        Average Orders
# 4           Most Orders

# %% [markdown]
# # 2. Grouping Data w/ Pandas

# %%
#use the groupby() function
df.groupby('product_name')

# %% [markdown]
# # 4. Aggregating Data w/ agg()

# %%
#performing a single aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
#aggregating without the use of agg()
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
#dot notation vs square brackets: aggregating w/out the use of agg()
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
#peforming multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # 5. Aggregating Data w/ transform()

# %%
#create a customer loytalty flag using loc()

# %%
#split the data into groups based on the 'user_id' column and apply transform 'order_number' to generate max orders per user
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order first_or_repeat_order  \
# 0                  8                     NaN           First Order
# 1                  7                    15.0          Repeat Order
# 2                 12                    21.0          Repeat Order
# 3                  7                    29.0          Repeat Order
# 4                 15                    28.0          Repeat Order
#
#    product_id  add_to_cart_order  reordered product_name  aisle_id  \
# 0         196                  1          0         Soda        77
# 1         196                  1          1         Soda        77
# 2         196                  1          1         Soda        77
# 3         196                  1          1         Soda        77
# 4         196                  1          1         Soda        77
#
#    department_id  prices        price_label     busiest_day    busiest_days  \
# 0              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 1              7     9.0  Mid-range product  Regularly busy    Slowest days
# 2              7     9.0  Mid-range product  Regularly busy    Slowest days
# 3              7     9.0  Mid-range product      Least busy    Slowest days
# 4              7     9.0  Mid-range product      Least busy    Slowest days
#
#   busiest_period_of_day  max_order
# 0        Average Orders         10
# 1        Average Orders         10
# 2           Most Orders         10
# 3        Average Orders         10
# 4           Most Orders         10

# %%
#check values of new max_order column
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# 13   2715276       15    prior            21                   1
# 14    487368       15    prior            22                   1
# 15   2293453       19    prior             2                   5
# 16   1973799       19    prior             5                   6
# 17    532817       19    prior             7                   4
# 18   1573906       21    prior            10                   3
# 19   1593000       31    prior            10                   3
# 20   2231262       31    prior            17                   3
# 21   2580647       43    prior             6                   4
# 22   2187180       43    prior             9                   4
# 23   2497897       52    prior             1                   1
# 24   1318871       52    prior             2                   1
# 25   1261384       52    prior             3                   1
# 26    580568       52    prior             5                   2
# 27   2428073       52    prior             7                   2
# 28    342306       52    prior             9                   1
# 29   1520353       52    prior            10                   2
# 30   2542086       52    prior            11                   2
# 31    944694       52    prior            12                   1
# 32   1268191       52    prior            15                   2
# 33   1122089       52    prior            17                   2
# 34   1498922       52    prior            18                   2
# 35    180919       52    prior            19                   3
# 36   2695875       52    prior            21                   5
# 37   3205960       67    prior             1                   3
# 38    970922       67    prior             2                   1
# 39    596585       67    prior             3                   1
# 40   2037087       67    prior             4                   2
# 41   2474111       67    prior             5                   3
# 42   1568481       67    prior             6                   3
# 43   2048527       67    prior             8                   2
# 44   2389031       67    prior             9                   2
# 45   2378562       67    prior            10                   1
# 46   1515698       67    prior            11                   1
# 47   1928050       67    prior            12                   2
# 48   1949274       67    prior            13                   1
# 49    551869       67    prior            14                   1
# 50    768572       67    prior            16                   4
# 51    150528       67    prior            18                   5
# 52     29758       67    prior            19                   0
# 53   1558976       67    prior            21                   1
# 54    863974       67    prior            22                   1
# 55   2308399       67    prior            23                   1
# 56   2759128       81    prior             3                   1
# 57   1812985       81    prior             5                   2
# 58   1889835       82    prior             1                   3
# 59    499460       82    prior             3                   5
# 60   2728456       82    prior             4                   0
# 61   2653743       82    prior             6                   4
# 62   1358880       82    prior             9                   1
# 63    343588       82    prior            10                   2
# 64   3034663       82    prior            15                   2
# 65    147262       82    prior            18                   1
# 66   3144004       82    prior            19                   2
# 67   2126069       98    prior             3                   0
# 68   2210120       98    prior             7                   5
# 69    681011       98    prior             9                   3
# 70   2846344       98    prior            11                   4
# 71    747431       98    prior            12                   6
# 72   2383054       98    prior            13                   4
# 73   1993729       98    prior            14                   5
# 74   1403849      109    prior             3                   3
# 75    520620      120    prior             1                   3
# 76   3273029      120    prior             3                   2
# 77   1861943      185    prior             2                   1
# 78   2040988      195    prior             1                   1
# 79   1680569      195    prior             8                   1
# 80    276171      195    prior            19                   5
# 81   2744976      195    prior            22                   5
# 82   2781919      195    prior            25                   1
# 83   1738718      195    prior            31                   2
# 84   3058369      195    prior            34                   3
# 85   1485596      195    prior            37                   2
# 86    417035      195    prior            40                   3
# 87   1615297      195    prior            47                   5
# 88   1765587      195    prior            52                   3
# 89    745908      195    prior            57                   4
# 90   2505656      222    prior            17                   2
# 91   3268370      222    prior            38                   5
# 92   2016711      290    prior             9                   5
# 93   2706088      290    prior            28                   6
# 94   1952286      331    prior             6                   5
# 95   3226575      360    prior             1                   5
# 96   1469869      377    prior             3                   5
# 97   1927023      387    prior             2                   4
# 98    858092      420    prior             4                   1
# 99    119314      420    prior             5                   3
#
#     order_hour_of_day  days_since_prior_order first_or_repeat_order  \
# 0                   8                     NaN           First Order
# 1                   7                    15.0          Repeat Order
# 2                  12                    21.0          Repeat Order
# 3                   7                    29.0          Repeat Order
# 4                  15                    28.0          Repeat Order
# 5                   7                    19.0          Repeat Order
# 6                   9                    20.0          Repeat Order
# 7                  14                    14.0          Repeat Order
# 8                  16                     0.0          Repeat Order
# 9                   8                    30.0          Repeat Order
# 10                  9                     7.0          Repeat Order
# 11                 16                     8.0          Repeat Order
# 12                 11                     7.0          Repeat Order
# 13                  9                     7.0          Repeat Order
# 14                 10                    14.0          Repeat Order
# 15                 14                     6.0          Repeat Order
# 16                 12                     8.0          Repeat Order
# 17                 17                     6.0          Repeat Order
# 18                 10                     6.0          Repeat Order
# 19                  8                     7.0          Repeat Order
# 20                 11                     8.0          Repeat Order
# 21                 16                     4.0          Repeat Order
# 22                 12                     3.0          Repeat Order
# 23                  9                     NaN           First Order
# 24                 10                     7.0          Repeat Order
# 25                 10                     7.0          Repeat Order
# 26                 10                     8.0          Repeat Order
# 27                  7                     8.0          Repeat Order
# 28                 11                     7.0          Repeat Order
# 29                 10                     8.0          Repeat Order
# 30                  9                     7.0          Repeat Order
# 31                 16                     6.0          Repeat Order
# 32                 11                     8.0          Repeat Order
# 33                 10                     6.0          Repeat Order
# 34                 10                    14.0          Repeat Order
# 35                  8                     8.0          Repeat Order
# 36                 10                    30.0          Repeat Order
# 37                 11                     NaN           First Order
# 38                 15                     5.0          Repeat Order
# 39                 13                     7.0          Repeat Order
# 40                  9                     8.0          Repeat Order
# 41                 14                     8.0          Repeat Order
# 42                 12                     7.0          Repeat Order
# 43                 11                     7.0          Repeat Order
# 44                 14                     7.0          Repeat Order
# 45                 10                     6.0          Repeat Order
# 46                 11                     7.0          Repeat Order
# 47                 12                     8.0          Repeat Order
# 48                 10                     6.0          Repeat Order
# 49                  9                     7.0          Repeat Order
# 50                 10                     9.0          Repeat Order
# 51                 16                     4.0          Repeat Order
# 52                 14                     9.0          Repeat Order
# 53                  9                     5.0          Repeat Order
# 54                 11                    14.0          Repeat Order
# 55                 14                    14.0          Repeat Order
# 56                  9                    14.0          Repeat Order
# 57                 20                    30.0          Repeat Order
# 58                 15                     NaN           First Order
# 59                 10                     5.0          Repeat Order
# 60                 11                    16.0          Repeat Order
# 61                  9                    13.0          Repeat Order
# 62                 10                    30.0          Repeat Order
# 63                 11                     1.0          Repeat Order
# 64                 11                    12.0          Repeat Order
# 65                 13                     7.0          Repeat Order
# 66                 15                     8.0          Repeat Order
# 67                  9                    25.0          Repeat Order
# 68                 14                     5.0          Repeat Order
# 69                  9                    30.0          Repeat Order
# 70                 13                    15.0          Repeat Order
# 71                 13                    30.0          Repeat Order
# 72                 11                    30.0          Repeat Order
# 73                  8                     8.0          Repeat Order
# 74                 17                     9.0          Repeat Order
# 75                 11                     NaN           First Order
# 76                  8                    19.0          Repeat Order
# 77                 12                    25.0          Repeat Order
# 78                 14                     NaN           First Order
# 79                  9                     4.0          Repeat Order
# 80                 11                     3.0          Repeat Order
# 81                 10                     7.0          Repeat Order
# 82                 14                     4.0          Repeat Order
# 83                  8                     4.0          Repeat Order
# 84                 10                     6.0          Repeat Order
# 85                 15                     0.0          Repeat Order
# 86                 16                     2.0          Repeat Order
# 87                 10                     2.0          Repeat Order
# 88                 12                     2.0          Repeat Order
# 89                 11                     3.0          Repeat Order
# 90                 12                     1.0          Repeat Order
# 91                 15                     1.0          Repeat Order
# 92                 19                     6.0          Repeat Order
# 93                 10                     7.0          Repeat Order
# 94                 16                    30.0          Repeat Order
# 95                 12                     NaN           First Order
# 96                 17                     3.0          Repeat Order
# 97                 10                    22.0          Repeat Order
# 98                 19                    30.0          Repeat Order
# 99                 19                    16.0          Repeat Order
#
#     product_id  add_to_cart_order  reordered product_name  aisle_id  \
# 0          196                  1          0         Soda        77
# 1          196                  1          1         Soda        77
# 2          196                  1          1         Soda        77
# 3          196                  1          1         Soda        77
# 4          196                  1          1         Soda        77
# 5          196                  1          1         Soda        77
# 6          196                  1          1         Soda        77
# 7          196                  2          1         Soda        77
# 8          196                  4          1         Soda        77
# 9          196                  1          1         Soda        77
# 10         196                  2          0         Soda        77
# 11         196                  6          1         Soda        77
# 12         196                  1          1         Soda        77
# 13         196                  1          1         Soda        77
# 14         196                  1          1         Soda        77
# 15         196                  3          0         Soda        77
# 16         196                 15          1         Soda        77
# 17         196                  1          1         Soda        77
# 18         196                  2          0         Soda        77
# 19         196                 17          0         Soda        77
# 20         196                 14          1         Soda        77
# 21         196                  9          0         Soda        77
# 22         196                  1          1         Soda        77
# 23         196                  4          0         Soda        77
# 24         196                  5          1         Soda        77
# 25         196                  3          1         Soda        77
# 26         196                  6          1         Soda        77
# 27         196                  5          1         Soda        77
# 28         196                  5          1         Soda        77
# 29         196                  4          1         Soda        77
# 30         196                  3          1         Soda        77
# 31         196                  7          1         Soda        77
# 32         196                  3          1         Soda        77
# 33         196                  4          1         Soda        77
# 34         196                  6          1         Soda        77
# 35         196                  4          1         Soda        77
# 36         196                  1          1         Soda        77
# 37         196                  1          0         Soda        77
# 38         196                  2          1         Soda        77
# 39         196                  2          1         Soda        77
# 40         196                  1          1         Soda        77
# 41         196                  2          1         Soda        77
# 42         196                  2          1         Soda        77
# 43         196                  1          1         Soda        77
# 44         196                  1          1         Soda        77
# 45         196                  1          1         Soda        77
# 46         196                  1          1         Soda        77
# 47         196                  1          1         Soda        77
# 48         196                  1          1         Soda        77
# 49         196                  1          1         Soda        77
# 50         196                  1          1         Soda        77
# 51         196                  1          1         Soda        77
# 52         196                  2          1         Soda        77
# 53         196                  2          1         Soda        77
# 54         196                  3          1         Soda        77
# 55         196                  1          1         Soda        77
# 56         196                  2          0         Soda        77
# 57         196                  1          1         Soda        77
# 58         196                  6          0         Soda        77
# 59         196                  2          1         Soda        77
# 60         196                  1          1         Soda        77
# 61         196                  5          1         Soda        77
# 62         196                  1          1         Soda        77
# 63         196                  1          1         Soda        77
# 64         196                  1          1         Soda        77
# 65         196                  1          1         Soda        77
# 66         196                  1          1         Soda        77
# 67         196                  7          0         Soda        77
# 68         196                  1          1         Soda        77
# 69         196                  1          1         Soda        77
# 70         196                  2          1         Soda        77
# 71         196                  4          1         Soda        77
# 72         196                  1          1         Soda        77
# 73         196                  2          1         Soda        77
# 74         196                  5          0         Soda        77
# 75         196                  2          0         Soda        77
# 76         196                  2          1         Soda        77
# 77         196                 10          0         Soda        77
# 78         196                  2          0         Soda        77
# 79         196                  2          1         Soda        77
# 80         196                  2          1         Soda        77
# 81         196                  2          1         Soda        77
# 82         196                  1          1         Soda        77
# 83         196                  2          1         Soda        77
# 84         196                  2          1         Soda        77
# 85         196                  2          1         Soda        77
# 86         196                  2          1         Soda        77
# 87         196                  2          1         Soda        77
# 88         196                  3          1         Soda        77
# 89         196                  3          1         Soda        77
# 90         196                  2          0         Soda        77
# 91         196                  6          1         Soda        77
# 92         196                  8          0         Soda        77
# 93         196                 16          1         Soda        77
# 94         196                  8          0         Soda        77
# 95         196                  1          0         Soda        77
# 96         196                  9          0         Soda        77
# 97         196                  3          0         Soda        77
# 98         196                  2          0         Soda        77
# 99         196                  2          1         Soda        77
#
#     department_id  prices        price_label     busiest_day    busiest_days  \
# 0               7     9.0  Mid-range product  Regularly busy  Regularly busy
# 1               7     9.0  Mid-range product  Regularly busy    Slowest days
# 2               7     9.0  Mid-range product  Regularly busy    Slowest days
# 3               7     9.0  Mid-range product      Least busy    Slowest days
# 4               7     9.0  Mid-range product      Least busy    Slowest days
# 5               7     9.0  Mid-range product  Regularly busy  Regularly busy
# 6               7     9.0  Mid-range product  Regularly busy    Busiest days
# 7               7     9.0  Mid-range product  Regularly busy    Busiest days
# 8               7     9.0  Mid-range product  Regularly busy    Busiest days
# 9               7     9.0  Mid-range product      Least busy    Slowest days
# 10              7     9.0  Mid-range product  Regularly busy    Busiest days
# 11              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 12              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 13              7     9.0  Mid-range product  Regularly busy    Busiest days
# 14              7     9.0  Mid-range product  Regularly busy    Busiest days
# 15              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 16              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 17              7     9.0  Mid-range product      Least busy    Slowest days
# 18              7     9.0  Mid-range product  Regularly busy    Slowest days
# 19              7     9.0  Mid-range product  Regularly busy    Slowest days
# 20              7     9.0  Mid-range product  Regularly busy    Slowest days
# 21              7     9.0  Mid-range product      Least busy    Slowest days
# 22              7     9.0  Mid-range product      Least busy    Slowest days
# 23              7     9.0  Mid-range product  Regularly busy    Busiest days
# 24              7     9.0  Mid-range product  Regularly busy    Busiest days
# 25              7     9.0  Mid-range product  Regularly busy    Busiest days
# 26              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 27              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 28              7     9.0  Mid-range product  Regularly busy    Busiest days
# 29              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 30              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 31              7     9.0  Mid-range product  Regularly busy    Busiest days
# 32              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 33              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 34              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 35              7     9.0  Mid-range product  Regularly busy    Slowest days
# 36              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 37              7     9.0  Mid-range product  Regularly busy    Slowest days
# 38              7     9.0  Mid-range product  Regularly busy    Busiest days
# 39              7     9.0  Mid-range product  Regularly busy    Busiest days
# 40              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 41              7     9.0  Mid-range product  Regularly busy    Slowest days
# 42              7     9.0  Mid-range product  Regularly busy    Slowest days
# 43              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 44              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 45              7     9.0  Mid-range product  Regularly busy    Busiest days
# 46              7     9.0  Mid-range product  Regularly busy    Busiest days
# 47              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 48              7     9.0  Mid-range product  Regularly busy    Busiest days
# 49              7     9.0  Mid-range product  Regularly busy    Busiest days
# 50              7     9.0  Mid-range product      Least busy    Slowest days
# 51              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 52              7     9.0  Mid-range product     Busiest day    Busiest days
# 53              7     9.0  Mid-range product  Regularly busy    Busiest days
# 54              7     9.0  Mid-range product  Regularly busy    Busiest days
# 55              7     9.0  Mid-range product  Regularly busy    Busiest days
# 56              7     9.0  Mid-range product  Regularly busy    Busiest days
# 57              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 58              7     9.0  Mid-range product  Regularly busy    Slowest days
# 59              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 60              7     9.0  Mid-range product     Busiest day    Busiest days
# 61              7     9.0  Mid-range product      Least busy    Slowest days
# 62              7     9.0  Mid-range product  Regularly busy    Busiest days
# 63              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 64              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 65              7     9.0  Mid-range product  Regularly busy    Busiest days
# 66              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 67              7     9.0  Mid-range product     Busiest day    Busiest days
# 68              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 69              7     9.0  Mid-range product  Regularly busy    Slowest days
# 70              7     9.0  Mid-range product      Least busy    Slowest days
# 71              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 72              7     9.0  Mid-range product      Least busy    Slowest days
# 73              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 74              7     9.0  Mid-range product  Regularly busy    Slowest days
# 75              7     9.0  Mid-range product  Regularly busy    Slowest days
# 76              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 77              7     9.0  Mid-range product  Regularly busy    Busiest days
# 78              7     9.0  Mid-range product  Regularly busy    Busiest days
# 79              7     9.0  Mid-range product  Regularly busy    Busiest days
# 80              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 81              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 82              7     9.0  Mid-range product  Regularly busy    Busiest days
# 83              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 84              7     9.0  Mid-range product  Regularly busy    Slowest days
# 85              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 86              7     9.0  Mid-range product  Regularly busy    Slowest days
# 87              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 88              7     9.0  Mid-range product  Regularly busy    Slowest days
# 89              7     9.0  Mid-range product      Least busy    Slowest days
# 90              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 91              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 92              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 93              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 94              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 95              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 96              7     9.0  Mid-range product  Regularly busy  Regularly busy
# 97              7     9.0  Mid-range product      Least busy    Slowest days
# 98              7     9.0  Mid-range product  Regularly busy    Busiest days
# 99              7     9.0  Mid-range product  Regularly busy    Slowest days
#
#    busiest_period_of_day  max_order
# 0         Average Orders         10
# 1         Average Orders         10
# 2            Most Orders         10
# 3         Average Orders         10
# 4            Most Orders         10
# 5         Average Orders         10
# 6            Most Orders         10
# 7            Most Orders         10
# 8            Most Orders         10
# 9         Average Orders         10
# 10           Most Orders         22
# 11           Most Orders         22
# 12           Most Orders         22
# 13           Most Orders         22
# 14           Most Orders         22
# 15           Most Orders          9
# 16           Most Orders          9
# 17        Average Orders          9
# 18           Most Orders         33
# 19        Average Orders         20
# 20           Most Orders         20
# 21           Most Orders         11
# 22           Most Orders         11
# 23           Most Orders         27
# 24           Most Orders         27
# 25           Most Orders         27
# 26           Most Orders         27
# 27        Average Orders         27
# 28           Most Orders         27
# 29           Most Orders         27
# 30           Most Orders         27
# 31           Most Orders         27
# 32           Most Orders         27
# 33           Most Orders         27
# 34           Most Orders         27
# 35        Average Orders         27
# 36           Most Orders         27
# 37           Most Orders         24
# 38           Most Orders         24
# 39           Most Orders         24
# 40           Most Orders         24
# 41           Most Orders         24
# 42           Most Orders         24
# 43           Most Orders         24
# 44           Most Orders         24
# 45           Most Orders         24
# 46           Most Orders         24
# 47           Most Orders         24
# 48           Most Orders         24
# 49           Most Orders         24
# 50           Most Orders         24
# 51           Most Orders         24
# 52           Most Orders         24
# 53           Most Orders         24
# 54           Most Orders         24
# 55           Most Orders         24
# 56           Most Orders          7
# 57        Average Orders          7
# 58           Most Orders         19
# 59           Most Orders         19
# 60           Most Orders         19
# 61           Most Orders         19
# 62           Most Orders         19
# 63           Most Orders         19
# 64           Most Orders         19
# 65           Most Orders         19
# 66           Most Orders         19
# 67           Most Orders         14
# 68           Most Orders         14
# 69           Most Orders         14
# 70           Most Orders         14
# 71           Most Orders         14
# 72           Most Orders         14
# 73        Average Orders         14
# 74        Average Orders          6
# 75           Most Orders          3
# 76        Average Orders          3
# 77           Most Orders          6
# 78           Most Orders         58
# 79           Most Orders         58
# 80           Most Orders         58
# 81           Most Orders         58
# 82           Most Orders         58
# 83        Average Orders         58
# 84           Most Orders         58
# 85           Most Orders         58
# 86           Most Orders         58
# 87           Most Orders         58
# 88           Most Orders         58
# 89           Most Orders         58
# 90           Most Orders         70
# 91           Most Orders         70
# 92        Average Orders         51
# 93           Most Orders         51
# 94           Most Orders          8
# 95           Most Orders          3
# 96        Average Orders          3
# 97           Most Orders          8
# 98        Average Orders         22
# 99        Average Orders         22

# %% [markdown]
# # 6. Deriving Columns w/ loc()

# %%
#create a "loyalty" flag based on the max_order column
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] > 10) & (ords_prods_merge['max_order'] <= 40), 'loyalty_flag'] = 'Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
#check frequency of new column 'loyalty_flag'
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: count, dtype: int64

# %%
#first 60 rows of df using user_id,loyalty_flag, and order_number
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New Customer             1
# 1         1      New Customer             2
# 2         1      New Customer             3
# 3         1      New Customer             4
# 4         1      New Customer             5
# 5         1      New Customer             6
# 6         1      New Customer             7
# 7         1      New Customer             8
# 8         1      New Customer             9
# 9         1      New Customer            10
# 10       15  Regular Customer            15
# 11       15  Regular Customer            17
# 12       15  Regular Customer            18
# 13       15  Regular Customer            21
# 14       15  Regular Customer            22
# 15       19      New Customer             2
# 16       19      New Customer             5
# 17       19      New Customer             7
# 18       21  Regular Customer            10
# 19       31  Regular Customer            10
# 20       31  Regular Customer            17
# 21       43  Regular Customer             6
# 22       43  Regular Customer             9
# 23       52  Regular Customer             1
# 24       52  Regular Customer             2
# 25       52  Regular Customer             3
# 26       52  Regular Customer             5
# 27       52  Regular Customer             7
# 28       52  Regular Customer             9
# 29       52  Regular Customer            10
# 30       52  Regular Customer            11
# 31       52  Regular Customer            12
# 32       52  Regular Customer            15
# 33       52  Regular Customer            17
# 34       52  Regular Customer            18
# 35       52  Regular Customer            19
# 36       52  Regular Customer            21
# 37       67  Regular Customer             1
# 38       67  Regular Customer             2
# 39       67  Regular Customer             3
# 40       67  Regular Customer             4
# 41       67  Regular Customer             5
# 42       67  Regular Customer             6
# 43       67  Regular Customer             8
# 44       67  Regular Customer             9
# 45       67  Regular Customer            10
# 46       67  Regular Customer            11
# 47       67  Regular Customer            12
# 48       67  Regular Customer            13
# 49       67  Regular Customer            14
# 50       67  Regular Customer            16
# 51       67  Regular Customer            18
# 52       67  Regular Customer            19
# 53       67  Regular Customer            21
# 54       67  Regular Customer            22
# 55       67  Regular Customer            23
# 56       81      New Customer             3
# 57       81      New Customer             5
# 58       82  Regular Customer             1
# 59       82  Regular Customer             3
